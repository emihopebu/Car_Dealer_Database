# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd
import sqlalchemy

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.cazoo.co.uk',
    'sec-ch-ua': '^\\^',
    'cazoo-language': 'en',
    'sec-ch-ua-mobile': '?1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Mobile Safari/537.36',
    'cazoo-market': 'gb',
    'sec-ch-ua-platform': '^\\^Android^\\^',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.cazoo.co.uk/cars/?page=2',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'base_device_id=b097f05c-2143-405b-af7d-ef4357fa9c4b; base_session_start_page=https://www.cazoo.co.uk/; base_referrer=https://www.google.com/; base_request=https://www.cazoo.co.uk/; base_session_id=feb6c49c-9db1-4b19-a9e7-ec900331927c; base_session_count=1; ajs_anonymous_id=^%^22b097f05c-2143-405b-af7d-ef4357fa9c4b^%^22; tracking-preferences-set=explicit; tracking-preferences=^{^%^22version^%^22:1^%^2C^%^22destinations^%^22:^{^%^22Amazon^%^20S3^%^22:true^%^2C^%^22DoubleClick^%^20Floodlight^%^22:true^%^2C^%^22Facebook^%^20Pixel^%^22:true^%^2C^%^22FullStory^%^22:true^%^2C^%^22GA^%^20Remarketing^%^20(Cazoo)^%^22:true^%^2C^%^22Google^%^20AdWords^%^20New^%^22:true^%^2C^%^22Google^%^20Analytics^%^22:true^%^2C^%^22Qualtrics^%^20(Cazoo)^%^22:true^}^}; _ga=GA1.3.994707839.1638206179; _gid=GA1.3.1277104535.1638206179; _gcl_au=1.1.1669561530.1638206179; fs_uid=rs.fullstory.com^#X95J5^#6383533006544896:5507329554669568/1669742178',
}

params = (
    ('sort', 'price-asc'),
)

response = requests.get('https://www.cazoo.co.uk/api/search', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json=response.json()
results_json
# Out:
# {'results': [{'createdAt': '2021-10-20T09:27:41.064Z',
#    'id': '4de06340-e392-5e0e-8d2a-87a39680f2e1',
#    'make': 'Dacia',
#    'model': 'Sandero Stepway',
#    'modelYear': 2012,
#    'displayVariant': '0.9L Laureate TCe',
#    'mileage': 62318,
#    'registrationYear': 2016,
#    'vrm': 'MP65KDJ',
#    'isForSubscription': False,
#    'isForPurchase': True,
#    'fuelType': {'description': 'Petrol',
#     'isEcoFriendly': False,
#     'isPlugin': False},
#    'images': {'main': {'url': 'https://res.cloudinary.com/cazoo/image/upload/c_scale,f_auto,h_405,q_auto,w_720/cazoo-imagery/car_gallery_images/UU15SDA1C54592884/IWYhNPYwsQU1VDcLYVHB.JPG'}},
#    'isPromoted': False,
#    'odometerReading': {'unit': 'mile', 'value': 62318},
#    'tradingMarket': 'gb',
#    'vehicleType': 'Car',
#    'pricing': {'fullPrice': {'centAmount': 600000,
#      'currencyCode': 'GBP',
#      'value': 6000},
#     'pcmPrice': {'pcp': {'centAmount': 9347,
#       'currencyCode': 'GBP',
# ...

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['results', 'filters', 'pagination'])

# %%
listing=results_json["results"]

# %%
len(listing)
# Out:
# 48

# %% [markdown]
# #### Step 6 - Find your Data

# %% [markdown]
# - brand
# - model
# - fuel type
# - miles
# - model year
# - price

# %%
#brand
listing[0]["make"]
# Out:
# 'Dacia'

# %%
#model
listing[0]["model"]
# Out:
# 'Sandero Stepway'

# %%
#fuel type
listing[0]["fuelType"]["description"]
# Out:
# 'Petrol'

# %%
#miles
listing[0]["mileage"]
# Out:
# 62318

# %%
#model year
listing[0]["modelYear"]
# Out:
# 2012

# %%
#price
listing[0]["pricing"]["fullPrice"]["value"]
# Out:
# 6000

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
#empty lists
brand=[]
model=[]
fuel_type=[]
miles=[]
model_year=[]
price=[]

for result in listing:
    
    #brand
    brand.append(result["make"])
    
    #model
    model.append(result["model"])
    
    #fuel type
    fuel_type.append(result["fuelType"]["description"])
    
    #miles
    miles.append(result["mileage"])
    
    #model year
    model_year.append(result["modelYear"])
    
    #price
    price.append(result["pricing"]["fullPrice"]["value"])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
car_df=pd.DataFrame({"Brand":brand,"Model":model,"Fuel Type":fuel_type,"Miles":miles,"Model Year":model_year,"Price":price})

# %%
car_df
# Out:
#          Brand            Model Fuel Type  Miles  Model Year  Price
# 0        Dacia  Sandero Stepway    Petrol  62318        2012   6000
# 1       Suzuki          Celerio    Petrol  10474        2015   6100
# 2           MG              MG3    Petrol  32757        2016   6175
# 3       Toyota             AYGO    Petrol  61886        2017   7000
# 4         Fiat              500    Petrol  18596        2017   7075
# 5     Vauxhall             Viva    Petrol  26434        2017   6700
# 6         Fiat              500    Petrol  15355        2020   7875
# 7         Fiat              500    Petrol  15866        2018   8125
# 8         Fiat              500    Petrol  17137        2015   8050
# 9         Fiat              500    Petrol   7056        2017   7950
# 10         Kia          Picanto    Petrol   7895        2018   7925
# 11      Toyota             AYGO    Petrol  15526        2017   7700
# 12        Fiat             Tipo    Petrol  52750        2017   7975
# ...

# %%
car_df.to_excel("car_single_page.xlsx", index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 20 pages)

# %%
headers = {
    'authority': 'www.cazoo.co.uk',
    'sec-ch-ua': '^\\^',
    'cazoo-language': 'en',
    'sec-ch-ua-mobile': '?1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Mobile Safari/537.36',
    'cazoo-market': 'gb',
    'sec-ch-ua-platform': '^\\^Android^\\^',
    'accept': '*/*',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.cazoo.co.uk/cars/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'base_device_id=b097f05c-2143-405b-af7d-ef4357fa9c4b; ajs_anonymous_id=^%^22b097f05c-2143-405b-af7d-ef4357fa9c4b^%^22; tracking-preferences-set=explicit; tracking-preferences=^{^%^22version^%^22:1^%^2C^%^22destinations^%^22:^{^%^22Amazon^%^20S3^%^22:true^%^2C^%^22DoubleClick^%^20Floodlight^%^22:true^%^2C^%^22Facebook^%^20Pixel^%^22:true^%^2C^%^22FullStory^%^22:true^%^2C^%^22GA^%^20Remarketing^%^20(Cazoo)^%^22:true^%^2C^%^22Google^%^20AdWords^%^20New^%^22:true^%^2C^%^22Google^%^20Analytics^%^22:true^%^2C^%^22Qualtrics^%^20(Cazoo)^%^22:true^}^}; _ga=GA1.3.994707839.1638206179; _gid=GA1.3.1277104535.1638206179; _gcl_au=1.1.1669561530.1638206179; base_session_start_page=https://www.cazoo.co.uk/; base_request=https://www.cazoo.co.uk/; base_session_id=cf9adacb-aed4-4859-94e2-78e817e9b801; base_session_count=2; fs_uid=rs.fullstory.com^#X95J5^#6383533006544896:5465559108182016/1669742178',
}
#empty lists
brand=[]
model=[]
fuel_type=[]
miles=[]
model_year=[]
price=[]
for i in range(1, 21):
    params = (
        ('page', str(i)),
        ('sort', 'price-asc'),
    )

    response = requests.get('https://www.cazoo.co.uk/api/search', headers=headers, params=params)
    
    
    results_json=response.json()
    
    listing=results_json["results"]
    for result in listing:
    
        #brand
        try:
            brand.append(result["make"])
        except:
            brand.append("")

        #model
        try:
            model.append(result["model"])
        except:
            model.append("")

        #fuel type
        try:
            fuel_type.append(result["fuelType"]["description"])
        except:
            fuel_type.append("")

        #miles
        try:
            miles.append(result["mileage"])
        except:
            miles.append("")

        #model year
        try:
            model_year.append(result["modelYear"])
        except:
            model_year.append("")

        #price
        try:
            price.append(result["pricing"]["fullPrice"]["value"])
        except:
            price.append("")
        
car_df_multiple=pd.DataFrame({"Brand":brand,"Model":model,"Fuel Type":fuel_type,"Miles":miles,"Model Year":model_year,"Price":price})

car_df_multiple
# Out:
#         Brand            Model Fuel Type  Miles  Model Year Price
# 0       Dacia  Sandero Stepway    Petrol  62318        2012  6000
# 1      Suzuki          Celerio    Petrol  10474        2015  6100
# 2          MG              MG3    Petrol  32757        2016  6175
# 3      Suzuki          Celerio    Petrol  29972        2015  6500
# 4      Toyota             AYGO    Petrol  61886        2017  7000
# ..        ...              ...       ...    ...         ...   ...
# 955  Vauxhall            Corsa    Petrol      2        2021
# 956  Vauxhall            Corsa    Petrol      3        2021
# 957  Vauxhall            Corsa    Petrol      2        2021
# 958  Vauxhall            Corsa    Petrol      3        2021
# 959  Vauxhall            Corsa    Petrol      3        2021
#
# [960 rows x 6 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
car_df_multiple.to_excel("car_multiple_pages.xlsx", index=False)

# %% [markdown]
# #### Step 11 - PostgreSQL

# %%
#create sqlalchemy engine
engine=sqlalchemy.create_engine('postgresql://postgres:12345@localhost:5432')
car_df_multiple.to_sql("car_dealer",engine,index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1900/2067099189.py in <module>
#       1 #create sqlalchemy engine
#       2 engine=sqlalchemy.create_engine('postgresql://postgres:12345@localhost:5432')
# ----> 3 car_df_multiple.to_sql("car_dealer",engine,index=False)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
# ...
